# %%
 from google.colab import drive
 drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
health_en_file = "/content/drive/MyDrive/health_domain_cleaned/single_files/health_data.en"

health_hi_file = "/content/drive/MyDrive/health_domain_cleaned/single_files/health_data.hi"

# %%
def create_df(src_file, tgt_file):
  src = []
  tgt = []

  with open(src_file, 'r') as src_, open(tgt_file, 'r') as tgt_:
    src_lines = src_.readlines()
    tgt_lines = tgt_.readlines()

  for line_index in range(len(src_lines)):
    src.append(src_lines[line_index].strip('\n'))
    tgt.append(tgt_lines[line_index].strip('\n'))

  df = pd.DataFrame({'src_sentence': src,
                     'tgt_sentence': tgt})

  return df

# %%
df_health = create_df(health_en_file, health_hi_file)

# %%
df_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5464 entries, 0 to 5463
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   src_sentence  5464 non-null   object
#  1   tgt_sentence  5464 non-null   object
# dtypes: object(2)
# memory usage: 85.5+ KB

# %%
df_health.head(20)
# Out:
#                                          src_sentence                                       tgt_sentence
# 0   ﻿A paragraph from the author book on cancer, p...  कैन्सर के बारे में लेखक की एक पुस्तक, जो 1973 ...
# 1   Doing nothing neither diagnosing nor treating ...  कुछ भी न करना जब तक कैन्सर के मरीज के मर्ज़ से ...
# 2   It is refusing to interfere backing the refusa...  यह अस्वीकृति को एक सुयोग्य आश्वासन या सोच-समझ ...
# 3   Agreed that there is never nothing to be done,...  माना कि कभी भी कुछ न करने की नौबत नहीं आती, पर...
# 4   It cannot be overemphasized that a doctor is a...  इस पर अधिक ज़ोर देने की आवश्यकता हो ही नहीं सक...
# 5   Should a patient ask him whether the former co...  यदि कोई मरीज उससे पूछे कि कहीं वह चिकित्सकीय अ...
# 6   The realization that the path of Mary is prefe...  कैन्सर विज्ञान तक के क्षेत्र में मेरी का मार्ग...
# 7   The EKF machine, a cardiologist commented, has...  एक हृदय रोग विशेषज्ञ ने टिप्पणी की है कि ई के ...
# 8   The harm is in terms of the cardiac neurosis t...  यह तबाही इस मशीन द्वारा जनित हृदय विक्षिप्ति क...
# 9   Christiaan Barnard talks of the EKG electrical...  क्रिश्चियन बर्नार्ड ईकेजी के "विद्युतीय आरेख" ...
# 10  Harrison remarks that physicians suffer from E...  हैरिसन ने टिप्पणी की है कि चिकित्सक लोग ईकेजीआ...
# 11  Kraus rightly said that Diagnosis is one of th...  क्राउस ने सही ही कहा है कि "निदान सर्वाधिक साम...
# 12  We have by now been able to evolve an understa...  अबतक हम लोग यह बोध विकसित करने में सक्षम हो गए...
# 13  Having made a diagnosis, treatment is not a must.  एकबार यदि निदान हो जाने पर उपचार अपरिहार्य नही...
# 14  If the cancer diseases, the minimal need be done.  यदि कैन्सर तकलीफदेह है, तो अल्पतम ही किया जाना...
# 15  Today, mere lumpectomy is followed by results ...  आजकल, आमूल शल्य-क्रिया के बाद स्तन कैन्सर के स...
# 16  Such minimal therapy is applicable to other ca...  ऐसा न्यूनतम उपचार अन्य प्रकार के कैसरों में भी...
# 17  Cancerologists are not exempt from treating pe...  कैन्सर विशेषज्ञों को और अधिक धन कमाने के लिए "...
# 18  Over years, cancer operations were done more f...  सालों से कैन्सर के ऑपरेशन मरीज के लाभ के बजाय ...
# 19  The amount of unnecessary surgery today vindic...  'अनावश्यक शल्य-क्रिया' की वर्तमान दर शल्य चिकि...
